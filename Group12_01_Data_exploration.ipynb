# %% [markdown]
# <a href="https://colab.research.google.com/github/cara-jvr/mit-805-group-project/blob/main/Group12_01_Data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

# creating a Spark Session Object
spark = (
    SparkSession.builder
    .appName("Big-Data-Project")
    .master("local[*]")
    .getOrCreate()
)
sc = spark.sparkContext
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://015b8ca88465:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Big-Data-Project</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# import libraries
from pyspark.sql.functions import split, explode, col, desc, sum as _sum
import pyarrow.parquet as pq
import glob
import pandas as pd

# %%
# importing raw files for NYC High Volume FHV Trip Data (available at: https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page)
list_files = ["fhvhv_tripdata_2023-01.parquet",
              "fhvhv_tripdata_2023-02.parquet",
             "fhvhv_tripdata_2023-03.parquet",
             "fhvhv_tripdata_2023-04.parquet",
              "fhvhv_tripdata_2023-05.parquet",
              "fhvhv_tripdata_2023-06.parquet"]
df = spark.read.parquet(*list_files)

# %%
# size of uncompressed raw file
uncompressed_bytes = 0

for file in list_files:
  file_metadata = pd.read_metadata(file)
  for i in range(metadata.num_row_groups):
    uncompressed_bytes += metadata.row_groups(i).total_byte_size
uncompressed_gb = uncompressed_bytes /(1024**3)
uncompressed_gb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12401/1266687921.py in <cell line: 0>()
#       4 for file in list_files:
#       5   file_metadata = pq.read_metadata(file)
# ----> 6   for i in range(metadata.num_row_groups):
#       7     uncompressed_bytes += metadata.row_groups(i).total_byte_size
#       8 uncompressed_gb = uncompressed_bytes /(1024**3)
#
# NameError: name 'metadata' is not defined

# %%
# filtering dataset for processing

# %%
# EDA
